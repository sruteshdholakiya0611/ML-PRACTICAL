# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Churn_Modelling.csv')
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df = pd.read_csv("Churn_Modelling.csv")
df.shape
# Out:
# (10000, 14)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df.values
# Out:
# array([[1, 15634602, 'Hargrave', ..., 1, 101348.88, 1],
#        [2, 15647311, 'Hill', ..., 1, 112542.58, 0],
#        [3, 15619304, 'Onio', ..., 0, 113931.57, 1],
#        ...,
#        [9998, 15584532, 'Liu', ..., 1, 42085.58, 1],
#        [9999, 15682355, 'Sabbatini', ..., 0, 92888.52, 1],
#        [10000, 15628319, 'Walker', ..., 0, 38190.78, 0]], dtype=object)

# %%
type(df.values)
# Out:
# numpy.ndarray

# %%
a = pd.read_csv("Churn_Modelling.csv", usecols = ['Gender','Age','Tenure','Balance'])
a.head(15)
# Out:
#     Gender  Age  Tenure    Balance
# 0   Female   42       2       0.00
# 1   Female   41       1   83807.86
# 2   Female   42       8  159660.80
# 3   Female   39       1       0.00
# 4   Female   43       2  125510.82
# 5     Male   44       8  113755.78
# 6     Male   50       7       0.00
# 7   Female   29       4  115046.74
# 8     Male   44       4  142051.07
# 9     Male   27       2  134603.88
# 10    Male   31       6  102016.72
# 11    Male   24       3       0.00
# 12  Female   34      10       0.00
# 13  Female   25       5       0.00
# 14  Female   35       7       0.00

# %%
b = pd.read_csv("Churn_Modelling.csv", nrows = 800)
b.shape
# Out:
# (800, 14)

# %%
b = pd.read_csv("Churn_Modelling.csv", skiprows = 1000)
b.shape
# Out:
# (9000, 14)

# %%
sample1 = df.sample(n=2222)
sample1.shape
# Out:
# (2222, 14)

# %%
sample1 = df.sample(frac = 0.4)
sample1.shape
# Out:
# (4000, 14)

# %%
df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
missing = np.random.randint(1000, size = 30)
df.loc[missing,['HasCrCard','IsActiveMember']] = np.nan
df.isna().sum()
# Out:
# RowNumber           0
# CustomerId          0
# Surname             0
# CreditScore         0
# Geography           0
# Gender              0
# Age                 0
# Tenure              0
# Balance             0
# NumOfProducts       0
# HasCrCard          30
# IsActiveMember     30
# EstimatedSalary     0
# Exited              0
# dtype: int64

# %%
missing = np.random.randint(5000, size = 80)
df.iloc[missing, -5] = np.nan
df.isna().sum()
# Out:
# RowNumber           0
# CustomerId          0
# Surname             0
# CreditScore         0
# Geography           0
# Gender              0
# Age                 0
# Tenure              0
# Balance             0
# NumOfProducts      80
# HasCrCard          30
# IsActiveMember     30
# EstimatedSalary     0
# Exited              0
# dtype: int64

# %%
mode = df['Geography'].value_counts().index[0]
df['Geography'].fillna(value = mode, inplace = True )
print(df)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df['Age'].value_counts()
# Out:
# 37    478
# 38    477
# 35    474
# 36    456
# 34    447
#      ...
# 92      2
# 82      1
# 88      1
# 85      1
# 83      1
# Name: Age, Length: 70, dtype: int64

# %%
avg = df['Exited'].mean()
df['Exited'].fillna(value = avg, inplace = True)
df['Exited'].value_counts()
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %%
df.dropna(axis = 0, how = 'any', inplace = True)
df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
france_churn = df[(df.Age == 30)&(df.Exited == 1)]
france_churn.Geography.value_counts()
# Out:
# Germany    9
# Spain      9
# France     6
# Name: Geography, dtype: int64

# %%
# Groupby function
gen = df.groupby("Age")
gen.first()
# Out:
#      RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Tenure  \
# Age
# 18         747    15787619     Hsieh          844    France    Male       2
# 19          58    15647091  Endrizzi          725   Germany    Male       0
# 20         234    15723886     Fiore          767   Germany    Male       3
# 21          70    15755648    Pisano          675    France  Female       8
# 22          87    15762418      Gant          750     Spain    Male       3
# ..         ...         ...       ...          ...       ...     ...     ...
# 83        9310    15621644  Lombardi          678   Germany    Male       6
# 84        3388    15798024      Lori          537   Germany    Male       8
# 85        3034    15578006       Yao          787    France  Female      10
# 88        2459    15813303   Rearick          513     Spain    Male      10
# 92        6444    15764927    Rogova          753    France    Male       3
#
# ...

# %%
gen = df.groupby(["Age", "Gender"])
gen.all()
# Out:
#             RowNumber  CustomerId  Surname  CreditScore  Geography  Tenure  \
# Age Gender
# 18  Female       True        True     True         True       True    True
#     Male         True        True     True         True       True    True
# 19  Female       True        True     True         True       True    True
#     Male         True        True     True         True       True   False
# 20  Female       True        True     True         True       True   False
# ...               ...         ...      ...          ...        ...     ...
# 84  Female       True        True     True         True       True    True
#     Male         True        True     True         True       True    True
# 85  Female       True        True     True         True       True    True
# 88  Male         True        True     True         True       True    True
# 92  Male         True        True     True         True       True    True
#
# ...

# %%
kk = df.groupby(["CreditScore", "Gender"])
print(kk.groups)
# Out:
# {(350, 'Female'): [8762, 9624], (350, 'Male'): [1631, 1838, 8723], (351, 'Female'): [2473], (358, 'Female'): [1962], (359, 'Female'): [1405], (363, 'Female'): [1193], (365, 'Male'): [2579], (367, 'Male'): [8154], (373, 'Male'): [9356], (376, 'Female'): [7, 942], (382, 'Male'): [9210], (383, 'Female'): [5494], (386, 'Female'): [5285], (395, 'Female'): [6253], (399, 'Male'): [1201], (401, 'Male'): [2748], (404, 'Female'): [2115], (405, 'Male'): [5357, 7671], (407, 'Male'): [4911], (408, 'Female'): [3531], (408, 'Male'): [8971], (410, 'Female'): [4659, 5488], (410, 'Male'): [8137], (411, 'Female'): [4840, 9171], (411, 'Male'): [29], (412, 'Male'): [8826], (413, 'Male'): [99, 4466, 6360], (414, 'Male'): [2689, 9264], (415, 'Male'): [1528, 3615, 6433], (416, 'Female'): [79, 6361], (416, 'Male'): [149, 8790], (417, 'Male'): [553], (418, 'Female'): [3889, 9357], (418, 'Male'): [6946, 7330, 7593, 9522], (419, 'Female'): [9407], (420, 'Female'): [1107, 3389, 4933], (421, 'Male'): [813, 8113, 
# ...

# %%
df.groupby("Age").sum()
# Out:
#      RowNumber  CustomerId  CreditScore  Tenure     Balance  NumOfProducts  \
# Age
# 18      124120   345471878        15107     106  1741730.65           33.0
# 19      134689   423839758        17972     137  1903568.57           37.0
# 20      214353   628217868        26602     203  3041555.60           62.0
# 21      246345   831947324        34306     253  4024124.79           88.0
# 22      398798  1301792230        52792     471  5611889.97          126.0
# ..         ...         ...          ...     ...         ...            ...
# 83        9310    15621644          678       6   123356.63            1.0
# 84        6920    31451275          945      16   180115.73            2.0
# 85        3034    15578006          787      10        0.00            2.0
# 88        2459    15813303          513      10        0.00            2.0
# 92       13204    31425805         1458       4   247589.55            3.0
#
#      HasCrCard  IsActiveMember  EstimatedSalary  Exited
# Age
# ...

# %%
df.groupby("Surname", sort = False).sum()
# Out:
#            RowNumber  CustomerId  CreditScore  Age  Tenure     Balance  \
# Surname
# Hargrave           1    15634602          619   42       2        0.00
# Hill           89037   266309903        11164  621      71  1374602.43
# Onio           39260   125511717         4766  275      39   740223.12
# Boni           96446   220206120         9006  574      49  1593837.80
# Mitchell       85486   298028513        12694  766      99  1576866.97
# ...              ...         ...          ...  ...     ...         ...
# Salinas         9951    15638494          625   39      10   129845.26
# Cleveland       9953    15696355          724   37       6   125489.40
# Kashiwagi       9956    15611338          714   29       4        0.00
# Aldridge        9962    15566543          573   44       9        0.00
# Burbidge        9982    15672754          498   42       3   152039.70
#
#            NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# Surname
# ...

# %%
df.groupby("Surname", sort = True).sum()
# Out:
#           RowNumber  CustomerId  CreditScore  Age  Tenure    Balance  \
# Surname
# Abazu          8382    31284947         1294   60      15   85534.83
# Abbie           842    15737792          818   31       1  186796.37
# Abbott        16940    62783217         2757  133      10  218544.41
# Abdullah       8485    15601012          802   60       3   92887.06
# Abdulov       12413    31413350         1229   67      12  238695.57
# ...             ...         ...          ...  ...     ...        ...
# Zubarev       21432    46965262         2059  120      19       0.00
# Zubareva       2947    15727696          592   42       1  147249.29
# Zuev           1031    15681174          730   39       1  116537.60
# Zuyev          7561    31305404         1280   92      17  276751.47
# Zuyeva        14126    31396762         1330   73       6  106301.85
#
#           NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# Surname
# ...

# %%
agegrp = df.groupby("Geography")
agegrp.get_group("France")
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 6             7    15592531   Bartlett          822    France    Male   50
# 8             9    15792365         He          501    France    Male   44
# ...         ...         ...        ...          ...       ...     ...  ...
# 9994       9995    15719294       Wood          800    France  Female   29
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
agegrp = df.groupby(["Geography", "Gender"])
agegrp.get_group(("France", "Male"))
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography Gender  Age  \
# 6             7    15592531   Bartlett          822    France   Male   50
# 8             9    15792365         He          501    France   Male   44
# 9            10    15592389         H?          684    France   Male   27
# 10           11    15767821     Bearce          528    France   Male   31
# 20           21    15577657   McDonald          732    France   Male   41
# ...         ...         ...        ...          ...       ...    ...  ...
# 9985       9986    15586914     Nepean          659    France   Male   36
# 9988       9989    15589329    Pirozzi          775    France   Male   30
# 9993       9994    15569266     Rahman          644    France   Male   28
# 9995       9996    15606229   Obijiaku          771    France   Male   39
# 9996       9997    15569892  Johnstone          516    France   Male   35
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [58], in <cell line: 1>()
# ----> 1 reset = df.reset_index(inplace = False)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:5839, in DataFrame.reset_index(self, level, drop, inplace, col_level, col_fill)
#    5833         if lab is not None:
#    5834             # if we have the codes, extract the values with a mask
#    5835             level_values = algorithms.take(
# ...
